# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/hae.jpg')
img.shape
# Out:
# (721, 563, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (721, 563)

# %%
gray
# Out:
# array([[233, 233, 233, ..., 229, 229, 230],
#        [233, 233, 233, ..., 229, 229, 230],
#        [233, 233, 233, ..., 229, 229, 230],
#        ...,
#        [ 18,  18,  18, ...,  19,  19,  19],
#        [ 19,  19,  19, ...,  19,  19,  19],
#        [ 19,  19,  18, ...,  19,  19,  19]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/harrcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[123, 162, 309, 309]])

# %%
(x,y,w,h) = faces[0]
w,y,w,h
# Out:
# (309, 162, 309, 309)

# %%
face_img = cv2.rectangle(img,(x,y,),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    
    if img is None:
        print(f"Error: Could not load image from {image_path}")
        return None
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    print(faces)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/hae.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/hae.jpg')
plt.imshow(cropped_image)
# Out:
# [[123 162 309 309]]

# %%
original_image = cv2.imread('./test_images/hae2.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/hae2.jpg')

plt.imshow(cropped_image)
# Out:
# ()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4512\3903529698.py in <module>
#       1 cropped_image = get_cropped_image_if_2_eyes('./test_images/hae2.jpg')
#       2
# ----> 3 plt.imshow(cropped_image)
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2651         resample=None, url=None, data=None, **kwargs):
# -> 2652     __ret = gca().imshow(
#    2653         X, cmap=cmap, norm=norm, aspect=aspect,
#    2654         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5479                               **kwargs)
#    5480
# -> 5481         im.set_data(X)
#    5482         im.set_alpha(alpha)
#    5483         if im.get_clip_path() is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     704         if (self._A.dtype != np.uint8 and
#     705                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 706             raise TypeError("Image data of dtype {} cannot be converted to "
#     707                             "float".format(self._A.dtype))
#     708
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/drake',
#  './dataset/haerin',
#  './dataset/lebron',
#  './dataset/leo',
#  './dataset/yb']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# [[ 88 140 255 255]]
# Generating cropped images in folder:  ./dataset/cropped/drake
# ()
# [[155 303 258 258]]
# [[194  68 312 312]]
# ()
# ()
# [[ 80 145 332 332]]
# ()
# ()
# [[208 255 286 286]]
# [[171 107 216 216]]
# [[202  64 180 180]]
# [[130  39 153 153]]
# ()
# [[213  46 167 167]]
# [[127  42 123 123]]
# [[140  67 232 232]]
# [[299 142 220 220]]
# [[150 116 232 232]]
# [[125 108 357 357]]
# [[109 115 309 309]]
# ()
# [[177  13 296 296]]
# ()
# ()
# [[128  48 210 210]]
# [[118  87 229 229]]
# Error: Could not load image from ./dataset/drake\f92c4ce78469f3965c953f3fa84a22a7.jpgZone.Identifier
# ()
# Error: Could not load image from ./dataset/drake\iwussu1yrp4nlpml4efa.jpgZone.Identifier
# [[181  91 153 153]]
# Generating cropped images in folder:  ./dataset/cropped/haerin
# Error: Could not load image from ./dataset/haerin\0c3c53c42b1a516a9575fc838616406e.jpgZone.Identifier
# [[ 81 346  64  64]
#  [223  63 119 119]]
# Error: Could not load image from ./dataset/haerin\19dfbfccb8c9aed3053706c991048f53.jpgZone.Identifier
# [[206 637 187 187]]
# [[100 137 271 271]]
# Error: Could not load image from ./dataset/haerin\2abb5c307afade3463144bb329c0300f.jpgZone.Identifier
# [[247  95 130 130]]
# Error: Could not load image from ./dataset/haerin\475727acfdede12a1c182ac93f6bba84.jpgZone.Identifier
# ()
# Error: Could not load image from ./dataset/haerin\491dc0aa987b55c1796c3084e7e2cfd7.jpgZone.Identifier
# [[180 140 221 221]]
# Error: Could not load image from ./dataset/haerin\4d73dc2ec8dfdb6effbc25c6465447be.jpgZone.Identifier
# [[122 312 171 171]]
# Error: Could not load image from ./dataset/haerin\53f15b06525cc47b1edefbe21e8307b5.jpgZone.Identifier
# [[159 132 229 229]]
# Error: Could not load image from ./dataset/haerin\56bd1494ec758b0ba8abd5dd2db38f61.jpgZone.Identifier
# [[281 269 145 145]]
# Error: Could not load image from ./dataset/haerin\5bd23f4a20b24b4cd13ecd7cad594bbd.jpgZone.Identifier
# [[244 642  53  53]
#  [247 138 146 146]]
# Error: Could not load image from ./dataset/haerin\5c2f47b825f62a188fbe5b81b7b5ca80.jpgZone.Identifier
# [[554 983  56  56]
#  [297 134 196 196]]
# Error: Could not load image from ./dataset/haerin\5e0afea418f0232ad446366b73ce1df1.jpgZone.Identifier
# ()
# Error: Could not load image from ./dataset
# [[ 96 115 347 347]]
# [[159 106 162 162]]
# ()
# [[ 46 162 290 290]]
# [[121 131 299 299]]
# ()
# ()
# [[185 780 116 116]
#  [444 436 101 101]]
# [[ 98 126 235 235]]
# [[113 168 247 247]]
# [[193  80 162 162]]
# [[ 82 117 362 362]]
# [[ 98 168 335 335]]
# [[ 90 145 298 298]]
# ()
# [[149 127 226 226]]
# Generating cropped images in folder:  ./dataset/cropped/yb
# ()
# [[126 147 317 317]]
# [[175 187 140 140]
#  [380 635 116 116]]
# [[178 103 177 177]]
# [[225  64 131 131]]
# ()
# ()
# [[259 450 201 201]
#  [204 121 255 255]]
# [[204 114 268 268]]
# [[135 118 228 228]]
# [[267  89 187 187]]
# [[132 136 335 335]]
# ()
# [[124 134 218 218]]
# [[209 403 177 177]]
# [[245 139 147 147]]
# [[244 271 247 247]
#  [236 922  90  90]]
# ()
# [[ 41  95 309 309]]
# [[104  91 127 127]]
# [[115 178 212 212]]
# [[175 119 240 240]]
# [[246  78 303 303]]
# ()
# [[ 98 161 375 375]]
# [[255 117 194 194]]

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
cropped_img = get_cropped_image_if_2_eyes('./test_images/hae.jpg')
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')
# Out:
# [[123 162 309 309]]

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'drake': ['./dataset/cropped/drake\\drake1.png',
#   './dataset/cropped/drake\\drake10.png',
#   './dataset/cropped/drake\\drake11.png',
#   './dataset/cropped/drake\\drake12.png',
#   './dataset/cropped/drake\\drake13.png',
#   './dataset/cropped/drake\\drake14.png',
#   './dataset/cropped/drake\\drake15.png',
#   './dataset/cropped/drake\\drake16.png',
#   './dataset/cropped/drake\\drake2.png',
#   './dataset/cropped/drake\\drake3.png',
#   './dataset/cropped/drake\\drake4.png',
#   './dataset/cropped/drake\\drake5.png',
#   './dataset/cropped/drake\\drake6.png',
#   './dataset/cropped/drake\\drake7.png',
#   './dataset/cropped/drake\\drake8.png',
#   './dataset/cropped/drake\\drake9.png'],
#  'haerin': ['./dataset/cropped/haerin\\haerin1.png',
#   './dataset/cropped/haerin\\haerin10.png',
#   './dataset/cropped/haerin\\haerin11.png',
#   './dataset/cropped/haerin\\haerin12.png',
#   './dataset/cropped/haerin\\haerin13.png',
#   './dataset/cropped/haerin\\haerin14.png',
#   './dataset/cropped/haerin\\haerin15.png',
#   './dataset/cropped/haerin\\haerin16.png',
#   './dataset/cropped/haerin\\haerin17.png',
#   './dataset/cropped/haerin\\haerin2.png',
#   './dataset/cropped/haerin\\haerin3.png',
#   './dataset/cropped/haerin\\haerin4.png',
#   './dataset/cropped/haerin\\haerin5.png',
#   './dataset/cropped/haerin\\haerin6.png',
#   './dataset/cropped/haerin\\haerin7.png',
#   './dataset/cropped/haerin\\haerin8.png',
#   './dataset/cropped/haerin\\haerin9.png'],
#  'lebron': ['./dataset/cropped/lebron\\lebron1.png',
#   './dataset/cropped/lebron\\lebron10.png',
#   './dataset/cropped/lebron\\lebron11.png',
#   './dataset/cropped/lebron\\lebron12.png',
#   './dataset/cropped/lebron\\lebron13.png',
#   './dataset/cropped/lebron\\lebron14.png',
#   './dataset/cropped/lebron\\lebron15.png',
#   './dataset/cropped/lebron\\lebron16.png',
#   './dataset/cropped/lebron\\lebron17.png',
#   './dataset/cropped/lebron\\lebron18.png',
#   './dataset/cropped/lebron\\lebron19.png',
#   './dataset/cropped/lebron\\lebron2.png',
#   './dataset/cropped/lebron\\lebron20.png',
#   './dataset/cropped/lebron\\lebron21.png',
#   './dataset/cropped/lebron\\lebron3.png',
#   './dataset/cropped/lebron\\lebron4.png',
#   './dataset/cropped/lebron\\lebron5.png',
#   './dataset/cropped/lebron\\lebron6.png',
#   './dataset/cropped/lebron\\lebron7.png',
#   './dataset/cropped/lebron\\lebron8.png',
#   './dataset/cropped/lebron\\lebron9.png'],
#  'leo': ['./dataset/cropped/leo\\leo1.png',
#   './dataset/cropped/leo\\leo10.png',
#   './dataset/cropped/leo\\leo11.png',
#   './dataset/cropped/leo\\leo12.png',
#   './dataset/cropped/leo\\leo13.png',
#   './dataset/cropped/leo\\leo14.png',
#   './dataset/cropped/leo\\leo15.png',
#   './dataset/cropped/leo\\leo16.png',
#   './dataset/cropped/leo\\leo17.png',
#   './dataset/cropped/leo\\leo18.png',
#   './dataset/cropped/leo\\leo19.png',
#   './dataset/cropped/leo\\leo2.png',
#   './dataset/cropped/leo\\leo20.png',
#   './dataset/cropped/leo\\leo21.png',
#   './dataset/cropped/leo\\leo22.png',
#   './dataset/cropped/leo\\leo3.png',
#   './dataset/cropped/leo\\leo4.png',
#   './dataset/cropped/leo\\leo5.png',
#   './dataset/cropped/leo\\leo6.png',
#   './dataset/cropped/leo\\leo7.png',
#   './dataset/cropped/leo\\leo8.png',
#   './dataset/cropped/leo\\leo9.png'],
#  'yb': ['./dataset/cropped/yb\\yb1.png',
#   './dataset/cropped/yb\\yb10.png',
#   './dataset/cropped/yb\\yb11.png',
#   './dataset/cropped/yb\\yb12.png',
#   './dataset/cropped/yb\\yb13.png',
#   './dataset/cropped/yb\\yb14.png',
#   './dataset/cropped/yb\\yb15.png',
#   './dataset/cropped/yb\\yb16.png',
#   './dataset/cropped/yb\\yb17.png',
#   './dataset/cropped/yb\\yb18.png',
#   './dataset/cropped/yb\\yb19.png',
#   './dataset/cropped/yb\\yb2.png',
#   './dataset/cropped/yb\\yb20.png',
#   './dataset/cropped/yb\\yb21.png',
#   './dataset/cropped/yb\\yb3.png',
#   './dataset/cropped/yb\\yb4.png',
#   './dataset/cropped/yb\\yb5.png',
#   './dataset/cropped/yb\\yb6.png',
#   './dataset/cropped/yb\\yb7.png',
#   './dataset/cropped/yb\\yb8.png',
#   './dataset/cropped/yb\\yb9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'drake': 0, 'haerin': 1, 'lebron': 2, 'leo': 3, 'yb': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scaled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scaled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 91],
#        [ 76],
#        [ 71],
#        ...,
#        [191],
#        [ 64],
#        [  5]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (97, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.76

# %%
len(X_test)
# Out:
# 25

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       1.00      0.80      0.89         5
#            2       0.50      1.00      0.67         4
#            3       0.75      1.00      0.86         6
#            4       1.00      0.60      0.75         5
#
#     accuracy                           0.76        25
#    macro avg       0.85      0.76      0.75        25
# weighted avg       0.86      0.76      0.75        25

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.694286
# 1        random_forest    0.598095
# 2  logistic_regression    0.832381
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.76

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.76

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[2, 0, 2, 1, 0],
#        [1, 4, 0, 0, 0],
#        [0, 0, 4, 0, 0],
#        [0, 0, 0, 6, 0],
#        [0, 0, 1, 1, 3]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'drake': 0, 'haerin': 1, 'lebron': 2, 'leo': 3, 'yb': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\jjaco\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
